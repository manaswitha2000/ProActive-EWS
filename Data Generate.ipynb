# %% [markdown]
# Generating data from the file

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import math
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("data_less.csv")
df = pd.DataFrame(data)
df.head()
# Out:
#    Iteration#   VDX Type   Rec Size   TSN   Epoch Time   sample#  ECG1 #  \
# 0           1      16384        264    55   1661453752         1   0.268
# 1           1      16384        264    55   1661453752         2   0.436
# 2           1      16384        264    55   1661453752         3   0.680
# 3           1      16384        264    55   1661453752         4   0.802
# 4           1      16384        264    55   1661453752         5   0.750
#
#    ECG2 #  ECG3 #   aVL #  ...   Systolic   Diastolic   Map   BP epoch Time  \
# 0   0.068  -0.200 -0.1680  ...
# 1   0.013  -0.423 -0.2245  ...
# 2   0.085  -0.595 -0.3825  ...
# 3   0.401  -0.401 -0.6015  ...
# 4   1.113   0.363 -0.9315  ...
#
#    BP invalidation   BP systolic threshold Low  BP Systolic threshold High  \
# 0
# 1
# 2
# 3
# 4
#
#    BP Diastolic threshold Low  BP Diastolic threshold High Unnamed: 48
# 0                                                                  NaN
# ...

# %%
df.shape
# Out:
# (65534, 49)

# %%
df1 = df.iloc[:, 28] # 28 for spo2 29 for pulse 24 for RR for HR 20

# %%
col = []
for i in range(23,len(df1),24):
    if(df1[i]!='0'):
        col.append(int(df1[i]))
len(col)
# Out:
# 1209

# %%
col
# Out:
# [81,
#  81,
#  81,
#  81,
#  81,
#  81,
#  81,
#  81,
#  81,
#  81,
#  81,
#  81,
#  81,
#  80,
#  80,
#  80,
#  80,
#  80,
#  80,
#  79,
#  79,
#  79,
#  79,
#  79,
#  79,
#  79,
#  79,
#  79,
#  79,
#  79,
#  79,
#  79,
#  79,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  79,
#  79,
#  79,
#  79,
#  79,
#  79,
#  79,
#  79,
#  79,
#  79,
#  79,
#  79,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  79,
#  79,
#  79,
#  79,
#  79,
#  79,
#  79,
#  79,
#  79,
#  79,
#  79,
#  79,
#  79,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  79,
#  79,
#  79,
#  79,
#  79,
#  79,
#  79,
#  79,
#  79,
#  79,
#  79,
#  79,
#  79,
#  79,
#  79,
#  79,
#  79,
#  79,
#  79,
#  79,
#  79,
#  79,
# ...

# %% [markdown]
# ### for spo2

# %% [raw]
# import random
# id = []
# label = []
# #Range of spo2 is given here
# for i in range(0,len(col)):
#     id.append(i)
#     spo2 = int(col[i])
#     if(spo2 > 97):
#         label.append("No")
#     elif(spo2 > 95):
#         label.append("Mild")
#     elif(spo2 > 90):
#         label.append("Moderate")
#     else:
#         label.append("Severe")

# %% [raw]
# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# data = { 'ID': id,
#         'Spo2': col,
#         'Label': label}
# df = pd.DataFrame(data)

# %% [raw]
# df.to_csv('sleep_data_time.csv',index = False)

# %% [markdown]
# ### for pulse rate

# %% [raw]
# import random
# id = []
# label = []
# #Range of spo2 is given here
# for i in range(0,len(col)):
#     id.append(i)
#     pulse = int(col[i])
#     if(pulse < 100 && pulse > 60):
#         label.append("Normal")
#     else:
#         label.append("Abnormal")

# %% [raw]
# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# data = { 'ID': id,
#         'Pulse': col,
#         'Label': label}
# df = pd.DataFrame(data)

# %% [raw]
# df.to_csv('pulse_data_time.csv',index = False)

# %% [markdown]
# ### for Respiratory Rate

# %% [raw]
# import random
# id = []
# label = []
# #Range of spo2 is given here
# for i in range(0,len(col)):
#     id.append(i)
#     rr = int(col[i])
#     if(rr <= 20 and rr > 11):
#         label.append("Normal")
#     else:
#         label.append("Abnormal")

# %% [raw]
# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# data = { 'ID': id,
#         'RR': col,
#         'Label': label}
# df = pd.DataFrame(data)

# %% [raw]
# df.to_csv('RR_data_time.csv',index = False)

# %% [markdown]
# ### for heart rate

# %%
import random
id = []
label = []
#Range of spo2 is given here
for i in range(0,len(col)):
    id.append(i)
    HR = int(col[i])
    if(HR < 100 and HR > 60):
        label.append("Normal")
    else:
        label.append("Abnormal")

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
data = { 'ID': id,
        'HR': col,
        'Label': label}
df = pd.DataFrame(data)

# %%
df.to_csv('HR_data_time.csv',index = False)

# %% [markdown]
# ### for temperature

# %% [raw]
# import random
# id = []
# label = []
# #Range of spo2 is given here
# for i in range(0,len(col)):
#     id.append(i)
#     temp = int(col[i])
#     if(temp <= 98.9 and temp > 97.5):
#         label.append("Normal")
#     else:
#         label.append("Abnormal")

# %% [raw]
# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# data = { 'ID': id,
#         'RR': col,
#         'Label': label}
# df = pd.DataFrame(data)

# %% [raw]
# df.to_csv('Temp_data_time.csv',index = False)

# %% [markdown]
# # Generating dummy data

# %% [markdown]
# ## for spo2

# %%
import random
id = []
col = []
label = []
#Range of spo2 is given here
for i in range(0,500):
    id.append(i)
    spo2 = random.randint(85,100)
    col.append(spo2)
    if(spo2 > 97):
        label.append("No")
    elif(spo2 > 95):
        label.append("Mild")
    elif(spo2 > 90):
        label.append("Moderate")
    else:
        label.append("Severe")

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
data = { 'ID': id,
        'Spo2': col,
        'Label': label}
df = pd.DataFrame(data)

# %%
df.to_csv('sleep_data_time.csv',index = False)

# %% [markdown]
# ## for temperature

# %%
import random
id = []
col = []
label = []
#Range of spo2 is given here
for i in range(0,500):
    id.append(i)
    temp = random.uniform(35,38);# generates random float value 
    col.append(temp)
    if(temp > 36.1 and temp < 37.2):
        label.append("Normal")
    else:
        label.append("Abnormal")

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
data = { 'ID': id,
        'Temp': col,
        'Label': label}
df = pd.DataFrame(data)

# %%
df.to_csv('temp_data_time.csv',index = False)
